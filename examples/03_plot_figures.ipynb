# %%
import sys
sys.path.append('../')
from src.trainers import MenuTrainer

menu_trainer = MenuTrainer()
menu_trainer.load()
# Out:
# [ encoder ] total trainable parameters : 1328
# [ invertible ] total trainable parameters : 33220
# [ simulator ] total trainable parameters : 6509
# [ simulator - loaded checkpoint ]
# 	../src/simulators/menu/models/menu_dqn/3000K.pt
# [ amortizer - loaded checkpoint ]
# 	../data/menu/amortizer_models/default/iter300.pt

# %%
res = menu_trainer.valid(verbose=False)

# %%
from src.trainers import PnCTrainer

pnc_trainer = PnCTrainer()
pnc_trainer.load()
# Out:
# [ encoder ] total trainable parameters : 9448
# [ trial-attention ] total trainable parameters : 51808
# [ invertible ] total trainable parameters : 66180
# [ simulator ] total trainable parameters : 8634
# [ simulator - loaded checkpoint ]
# 	../src/simulators/pnc/models/pnc_dqn/0300K.pt
# [ amortizer - loaded checkpoint ]
# 	../data/pnc/amortizer_models/default/iter500.pt

# %%
res = pnc_trainer.valid(verbose=False)

# %%
from src.trainers import TypingTrainer

typing_trainer = TypingTrainer()
typing_trainer.load()
# Out:
# [ encoder ] total trainable parameters : 736
# [ trial-attention ] total trainable parameters : 68128
# [ invertible ] total trainable parameters : 32805
# [ simulator - loaded checkpoint ]
# 	../src/simulators/typing/models/supervisor/best_model.zip
# [ amortizer - loaded checkpoint ]
# 	../data/typing/amortizer_models/default/iter300.pt

# %%
res = typing_trainer.valid(verbose=False)

# %%
from src.utils.plot import (
    inference_time_by_trial_size,
    parameter_recovery_by_trial_size,
    significance_by_dataset_size
)

n_trial_arr = [4, 8, 16, 32, 64, 100, 200, 500]
inference_time_by_trial_size(typing_trainer, n_trial_arr)
# Out:
# 100%|██████████| 8/8 [00:14<00:00,  1.85s/it]

# %%
n_trial_arr = [4, 8, 16, 32, 64, 100, 200, 500]
parameter_recovery_by_trial_size(typing_trainer, n_trial_arr, repitition=100)
# Out:
# 100%|██████████| 8/8 [25:06<00:00, 188.31s/it]

# %%
n_user_arr = [10, 20, 40, 80, 160, 320, 640]
significance_by_dataset_size(typing_trainer, n_user_arr, repitition=100)
# Out:
# 100%|██████████| 1057/1057 [01:15<00:00, 13.92it/s]
